# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ndata=pd.read_csv('new_dstrIPC_1_2014.csv')
del ndata["Unnamed: 0"]
del ndata["Unnamed: 0.1"]
ndata = ndata[pd.notnull(ndata["lat"])]
ndata = ndata[pd.notnull(ndata["long"])]
ndata=ndata[ndata["District"]!="Total"]
ndata.head(25)
# Out:
#            States/UTs            District  Year  Murder  \
# 0      Andhra Pradesh           Anantapur  2014     134
# 1      Andhra Pradesh            Chittoor  2014      84
# 2      Andhra Pradesh            Cuddapah  2014      80
# 3      Andhra Pradesh       East Godavari  2014      64
# 4      Andhra Pradesh    Guntakal Railway  2014      14
# 5      Andhra Pradesh              Guntur  2014     105
# 6      Andhra Pradesh        Guntur Urban  2014      51
# 7      Andhra Pradesh             Krishna  2014      51
# 8      Andhra Pradesh             Kurnool  2014     118
# 9      Andhra Pradesh             Nellore  2014      78
# 10     Andhra Pradesh           Prakasham  2014      75
# 11     Andhra Pradesh         Rajahmundry  2014      18
# 12     Andhra Pradesh          Srikakulam  2014      30
# 13     Andhra Pradesh     Tirupathi Urban  2014      35
# 14     Andhra Pradesh     Vijayawada City  2014      23
# 15     Andhra Pradesh  Vijayawada Railway  2014       1
# 16     Andhra Pradesh       Visakha Rural  2014      43
# 17     Andhra Pradesh       Visakhapatnam  2014      38
# 18     Andhra Pradesh        Vizianagaram  2014      43
# 19     Andhra Pradesh       West Godavari  2014      90
# 21  Arunachal Pradesh               Anjaw  2014       0
# 22  Arunachal Pradesh           Changlang  2014       9
# 23  Arunachal Pradesh        Crime Branch  2014       0
# 24  Arunachal Pradesh       Dibang Valley  2014       0
# 25  Arunachal Pradesh         Kameng East  2014       4
#
#     Attempt to commit Murder  Culpable Homicide not amounting to Murder  \
# 0                        171                                          8
# 1                        170                                          2
# 2                        162                                          1
# 3                         84                                          2
# 4                          4                                          0
# 5                        137                                          4
# 6                         65                                          0
# 7                         47                                          1
# 8                        135                                          5
# 9                        117                                          4
# 10                        68                                          7
# 11                        18                                          1
# 12                        29                                          4
# 13                        72                                          2
# 14                        45                                          1
# 15                         1                                          1
# 16                        50                                          4
# 17                        57                                          0
# 18                        23                                          1
# 19                        85                                          4
# 21                         0                                          0
# 22                         3                                          0
# 23                         0                                          0
# 24                         0                                          0
# 25                         1                                          0
#
#     Attempt to commit Culpable Homicide  Rape  Custodial Rape  \
# 0                                     0    35               0
# 1                                     0    32               0
# 2                                     0    28               0
# 3                                     0    85               0
# 4                                     0     0               0
# 5                                     0    49               0
# 6                                     0    40               0
# 7                                     0    80               0
# 8                                     0    32               0
# 9                                     0    58               0
# 10                                    0    50               0
# 11                                    0    35               0
# 12                                    0    40               0
# 13                                    0    18               0
# 14                                    1    64               0
# 15                                    0     0               0
# 16                                    0    38               0
# 17                                    0    84               0
# 18                                    0    47               0
# 19                                    0   146               0
# 21                                    0     0               0
# 22                                    0     6               0
# 23                                    0     0               0
# 24                                    0     1               0
# 25                                    0     1               0
#
#     Custodial_Gang Rape    ...      Disclosure of Identity of Victims  \
# 0                     0    ...                                      0
# 1                     0    ...                                      0
# 2                     0    ...                                      0
# 23  28.217999  94.727753
# 24  28.217999  94.727753
# 25  28.217999  94.727753
#
# [25 rows x 95 columns]

# %%
ndata.pivot_table(values=['Murder'],index=["States/UTs"],aggfunc=np.sum)
# Out:
#                    Murder
# States/UTs
# A&N Islands            16
# Andhra Pradesh       2350
# Arunachal Pradesh     172
# Assam                2902
# Bihar                6806
# Chandigarh             48
# Chhattisgarh         1996
# D&N Haveli              8
# Daman & Diu            14
# Delhi UT             1172
# Goa                    68
# Gujarat              2248
# Haryana              2212
# Himachal Pradesh      260
# Jammu & Kashmir       312
# Jharkhand            3316
# Karnataka            3272
# Kerala                734
# Lakshadweep             0
# Madhya Pradesh       4548
# Maharashtra          5340
# Manipur               192
# Meghalaya             318
# Mizoram                84
# Nagaland              116
# Odisha               2900
# Puducherry             50
# Punjab               1534
# Rajasthan            3274
# Sikkim                 24
# Tamil Nadu           3610
# Telangana            2616
# Tripura               280
# Uttar Pradesh       10300
# Uttarakhand           436
# West Bengal          4740

# %%
mydata=ndata.groupby(['States/UTs'])['Murder','Rape'].sum()
mydata.plot(kind='bar',stacked=True)

# %%
mydata=ndata.groupby(['States/UTs'])["lat","long","Rape"].mean()
mydata
# Out:
#                          lat       long        Rape
# States/UTs
# A&N Islands        11.740087  92.658640   10.666667
# Andhra Pradesh     15.912900  79.739988   48.050000
# Arunachal Pradesh  28.217999  94.727753    4.368421
# Assam              26.200604  92.937574   70.714286
# Bihar              25.096074  85.313119   24.500000
# Chandigarh         30.733315  76.779418   59.000000
# Chhattisgarh       21.278657  81.866144   51.285714
# D&N Haveli         20.180867  73.016914    5.000000
# Daman & Diu        20.428283  72.839732    1.000000
# Delhi UT           28.704059  77.102490  110.315789
# Goa                15.299327  74.123996   31.666667
# Gujarat            22.258652  71.192380   20.512195
# Haryana            29.058776  76.085601   48.916667
# Himachal Pradesh   31.104829  77.173390   18.866667
# Jammu & Kashmir    33.778175  76.576171   11.033333
# Jharkhand          23.610181  85.279935   40.384615
# Karnataka          15.317277  75.713888   36.777778
# Kerala             10.850516  76.271083   64.142857
# Lakshadweep         8.295414  73.048982    1.000000
# Madhya Pradesh     22.973423  78.656894   92.290909
# Maharashtra        19.751480  75.713888   74.739130
# Manipur            24.663717  93.906269    7.500000
# Meghalaya          25.467031  91.366216   10.727273
# Mizoram            23.164543  92.937574   13.333333
# Nagaland           26.158435  94.562443    2.727273
# Odisha             20.951666  85.098524   54.944444
# Puducherry         11.914354  79.737194    5.000000
# Punjab             31.147130  75.341218   35.035714
# Rajasthan          27.023804  74.217933   89.500000
# Sikkim             27.532972  88.512218    9.400000
# Tamil Nadu         11.127122  78.656894   10.833333
# Telangana          18.112437  79.019300   75.307692
# Tripura            23.940848  91.988153   26.555556
# Uttar Pradesh      26.846709  80.946159   45.618421
# Uttarakhand        30.066753  79.019300   20.769231
# West Bengal        22.986757  87.854975  113.633333

# %%
from mpl_toolkits.basemap import Basemap
m=Basemap(projection='mill',llcrnrlat=mydata.lat.min()-2,urcrnrlat=mydata.lat.max()+2,llcrnrlon=mydata.long.min()-2,urcrnrlon=mydata.long.max()+2,resolution='c',epsg=4269)
x,y=m(tuple(mydata.long),tuple(mydata.lat))

# %%
for i in range(36):
    mydata.Rape[i]=mydata.Rape[i]/(mydata.Rape.max())

# %%
plt.figure(figsize=(20,10))
m.arcgisimage(service="NatGeo_World_Map", verbose=True)
for i in range(len(x)):
    m.plot(x[i],y[i],'ro',markersize=20, alpha=mydata.Rape[i] )
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/export?bbox=69.1923805,6.2954136,96.72775279999998,35.77817500000001&bboxSR=4269&imageSR=4269&size=400,428&dpi=96&format=png32&f=image
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3310: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3319: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3274: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3283: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
m1=Basemap(projection='mill',llcrnrlat=ndata.Dislat.min()-2,urcrnrlat=ndata.Dislat.max()+2,llcrnrlon=ndata.Dislong.min()-2,urcrnrlon=ndata.Dislong.max()+2,resolution='c',epsg=4269)
x,y=m(tuple(ndata.Dislong),tuple(ndata.Dislat))

# %%
plt.figure(figsize=(20,10))
m.arcgisimage(service="NatGeo_World_Map", verbose=True)
m.plot(x,y,'ro',markersize=5, alpha=0.3 )
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/export?bbox=69.1923805,6.2954136,96.72775279999998,35.77817500000001&bboxSR=4269&imageSR=4269&size=400,428&dpi=96&format=png32&f=image
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3310: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3319: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3274: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3283: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
color = np.random.rand(ndata["States/UTs"].unique().shape[0], 3)
plt.figure(figsize=(20,10))
m1=Basemap(projection='mill',llcrnrlat=mydata.lat.min()-2,urcrnrlat=mydata.lat.max()+2,llcrnrlon=mydata.long.min()-2,urcrnrlon=mydata.long.max()+2,resolution='c',epsg=4269)
m1.arcgisimage(service="NatGeo_World_Map", verbose=True)
c = 0
for i in ndata["States/UTs"].unique():
    x1, y1 = m(tuple(ndata.Dislong[(ndata["States/UTs"] == i)]), 
         tuple(ndata.Dislat[(ndata["States/UTs"] == i)]))
    m1.plot(x1,y1,'ro',markersize=5,alpha=0.9, color = color[c] )
    c += 1
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/export?bbox=69.1923805,6.2954136,96.72775279999998,35.77817500000001&bboxSR=4269&imageSR=4269&size=400,428&dpi=96&format=png32&f=image
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3310: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3319: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3274: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/manobhav/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3283: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
mydata1=ndata.groupby(['States/UTs'])['Murder','Rape','Kidnapping & Abduction_Total','Attempt to commit Rape','Dacoity'].sum()

# %%
mydata1.transpose().loc[:,["Uttar Pradesh","Bihar","Goa"]].plot(kind='pie',subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ecdf74860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ecde9c518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ecde04400>], dtype=object)
